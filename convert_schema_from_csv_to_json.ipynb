# %%
import ast

import json

import pandas as pd

raw_path = f"./data/schema/ontology.csv"
output_path = f"./data/schema/ontology.json"

colors = [
    "#ff6961",
    "#ffb480",
    "#f8f38d",
    "#42d6a4",
    "#08cad1",
    "#59adf6",
    "#5BC236",
    "#c780e8",
    "#f66d9b",
    "#9561e2",
]

# Renaming.
col_map = {
    f"domain": "domain",
    f"slot_name": "slot",
    f"possible_slot_values": "value",
    "categorical_values": "categorical_values",
    "extractive_values": "extractive_values",
    "abstractive_values": "abstractive_values",
    "time_values": "time_values",
    "Group ID": "group_id",
    "Must have": "must_have",
    "Global": "global",
    "Important slot(have chance to be improved)": "important_slot",
    "Parking Lot": "Parking Lot",
    "Driveway": "Driveway",
    "Highway": "Highway",
    "Roadway": "Roadway",
    "Intersection": "Intersection",
}
df = pd.read_csv(raw_path)[col_map.keys()]
df = df.rename(columns=col_map)
df["value"] = df["value"].apply(
    lambda x: list(map(lambda x: x if x.isupper()
                   else x.title(), ast.literal_eval(x)))
)
df = df.drop_duplicates(subset=["domain", "slot"])
df
# Out:
#                 domain                     slot  \
# 0             Adjuster        Explain Coverages
# 1             Adjuster     Permission to Record
# 2             Adjuster        Set up Inspection
# 3             Adjuster            Set up Rental
# 4          ContactInfo               First Name
# 5          ContactInfo                Last Name
# 6          ContactInfo             Home Address
# 7          ContactInfo             Phone Number
# 8          ContactInfo            Email Address
# 9          ContactInfo            Policy Number
# 10         ContactInfo            Date of Birth
# 11       DriverActions               Car Motion
# 12       DriverActions                    Speed
# 13       DriverActions             Distractions
# 14       DriverActions                    Brake
# 15       DriverActions                     Horn
# 16       DriverActions              Turn Signal
# 17       DriverActions  Traffic Controls Obeyed
# 18           Evidences            Police Report
# 19           Evidences   Police Department Name
# 20           Evidences                 Pictures
# 21           Evidences        Tickets Citations
# 22           Evidences     Police Report Number
# 23           Evidences               Skid Marks
# 24       InjuryDetails                Ambulance
# 25       InjuryDetails        Body Part Injured
# 26       InjuryDetails              Injury Type
# 27       InjuryDetails        Medical Treatment
# 28     AccidentDetails              Damage Part
# 29     AccidentDetails        Accident Location
# 30     AccidentDetails        Num of Passengers
# 31     AccidentDetails                Witnesses
# 32     AccidentDetails     Num of Involved Cars
# 33     AccidentDetails        Children Involved
# 34     AccidentDetails          Airbag Deployed
# 35     AccidentDetails                    Towed
# 36     AccidentDetails     Pedestrians Involved
# 37     AccidentDetails         Date of Accident
# 38     AccidentDetails         Time of Accident
# 39     AccidentDetails         Subjective Fault
# 40             CarInfo               Make/Model
# 41             CarInfo                Make Year
# 42             CarInfo                    Color
# 43                Trip      Destination of Trip
# 44                Trip          Purpose of Trip
# 45                Trip           Origin of Trip
# 46             CarInfo              Car Mileage
# 47             CarInfo    Rideshare (Uber/Lyft)
# 48  TrafficEnvironment       Weather Visibility
# 49  TrafficEnvironment     Obstructions to View
# 50  TrafficEnvironment           Road Condition
# 51  TrafficEnvironment           Traffic Signal
# 52  TrafficEnvironment     Description of Lanes
# 53  TrafficEnvironment             Num of Lanes
# 54  TrafficEnvironment        Traffic Condition
# 55  TrafficEnvironment              Speed Limit
# 56  TrafficEnvironment             Traffic Flow
# 57  TrafficEnvironment         Parking Lot Type
#
#                                                 value  categorical_values  \
# 0                                                  []                   0
# 1                                           [Yes, No]                   1
# 2                     [Photo Claim, Field Assignment]                   1
# 3                                           [Yes, No]                   1
# 4                                                  []                   0
# 5                                                  []                   0
# 6                                                  []                   0
# 7                                                  []                   0
# 8                                                  []                   0
# 9                                                  []                   0
# 10                                                 []                   0
# 11  [Traveling Forward, Backing, Turning, Changing...                   1
# 12                                                 []                   0
# 13  [Cellphone, Animals, Smoking, Passengers, Traf...                   1
# 14                                  [Yes, No, Unsure]                   1
# 15                                  [Yes, No, Unsure]                   1
# 16                                  [Yes, No, Unsure]                   1
# 17                                  [Yes, No, Unsure]                   1
# 18                                  [Yes, No, Unsure]                   1
# 19                                                 []                   0
# 20     [At Scene, After Accident, No Picture, Unsure]                   1
# 21  [Caller Party Cited, Other Party Cited, No Par...                   1
# 22                                                 []                   0
# 23                                  [Yes, No, Unsure]                   1
# 24                                  [Yes, No, Unsure]                   1
# 25  [Head, Neck, Shoulder, Chest, Abdomen, Back, L...                   1
# 26  [Bruise, Broken Fracture, Cut Scratch, Bleedin...                   1
# 27  [MRI, Surgery, Cat Scan, Hospitalization, ER, ...                   1
# 28  [Front, Right, Back, Left, Front Right, Front ...                   1
# 29  [Parking Lot, Driveway, Highway, Roadway, Inte...                   1
# 30                                 [0, 1, 2+, Unsure]                   1
# 31                                  [Yes, No, Unsure]                   1
# 32                              [1, 2, 3, 4+, Unsure]                   1
# 33                                  [Yes, No, Unsure]                   1
# 34                                  [Yes, No, Unsure]                   1
# 35                                  [Yes, No, Unsure]                   1
# 36                                  [Yes, No, Unsure]                   1
# 37                                                 []                   0
# 38                                                 []                   0
# 39                             [Caller, Other Driver]                   1
# 40                                                 []                   0
# 41                                                 []                   0
# 42                                                 []                   0
# 43                                                 []                   0
# 44                                                 []                   0
# 45                                                 []                   0
# 46                                                 []                   0
# 47                                  [Yes, No, Unsure]                   1
# 48  [Clear, Cloudy, Rainy, Snowy, Foggy, Windy, Ot...                   1
# 49                                  [Yes, No, Unsure]                   1
# 50  [Dry, Wet, Slippery, Debris, Potholes, Straigh...                   1
# 51  [Stop Sign, Yield Sign, Green Light, Yellow Li...                   1
# 52       [Normal, Turn Lane, Shoulder, Other, Unsure]                   1
# 53                              [1, 2, 3, 4+, Unsure]                   1
# 54            [Heavy, Moderate, Light, Other, Unsure]                   1
# 55                                                 []                   0
# 56                  [One-Way, Two-Way, Other, Unsure]                   1
# 57                  [Angled, Straight, Other, Unsure]                   1
#
#     extractive_values  abstractive_values  time_values  group_id  must_have  \
# 0                   1                   0            0       NaN        NaN
# 1                   0                   0            0       NaN        1.0
# 2                   0                   0            0       NaN        NaN
# 3                   0                   0            0       NaN        NaN
# 4                   1                   0            0       1.0        1.0
# 5                   1                   0            0       1.0        1.0
# 6                   1                   0            0       1.0        NaN
# 7                   1                   0            0       1.0        NaN
# 8                   1                   0            0       NaN        NaN
# 9                   1                   0            0       NaN        NaN
# 10                  1                   0            0       NaN        NaN
# 11                  0                   0            0       NaN        1.0
# 12                  1                   0            0       NaN        1.0
# 13                  0                   0            0       NaN        NaN
# 14                  0                   0            0       NaN        NaN
# 15                  0                   0            0       NaN        NaN
# 16                  0                   0            0       NaN        NaN
# 17                  0                   0            0       NaN        NaN
# 18                  0                   0            0       2.0        1.0
# 19                  1                   0            0       2.0        NaN
# 20                  0                   0            0       NaN        NaN
# 21                  0                   0            0       2.0        NaN
# 22                  1                   0            0       2.0        NaN
# 23                  0                   0            0       NaN        NaN
# 24                  0                   0            0       NaN        NaN
# 25                  0                   0            0       3.0        NaN
# 26                  0                   0            0       3.0        NaN
# 27                  0                   0            0       3.0        NaN
# 28                  0                   0            0       NaN        1.0
# 29                  0                   0            0       NaN        1.0
# 30                  0                   0            0       NaN        1.0
# 31                  0                   0            0       NaN        1.0
# 32                  0                   0            0       NaN        NaN
# 33                  0                   0            0       NaN        NaN
# 34                  0                   0            0       NaN        NaN
# 35                  0                   0            0       NaN        NaN
# 36                  0                   0            0       NaN        NaN
# 37                  1                   0            0       5.0        1.0
# 38                  1                   0            0       5.0        1.0
# 39                  0                   0            0       NaN        NaN
# 40                  1                   0            0       6.0        1.0
# 41                  1                   0            0       6.0        1.0
# 42                  1                   0            0       6.0        1.0
# 43                  1                   0            0       8.0        NaN
# 44                  1                   0            0       8.0        NaN
# 45                  1                   0            0       8.0        NaN
# 46                  1                   0            0       NaN        NaN
# 47                  0                   0            0       NaN        NaN
# 48                  0                   0            0       7.0        NaN
# 49                  0                   0            0       7.0        NaN
# 50                  0                   0            0       NaN        NaN
# 51                  0                   0            0       NaN        1.0
# 52                  0                   0            0       NaN        1.0
# 53                  0                   0            0       NaN        1.0
# 54                  0                   0            0       7.0        NaN
# 55                  1                   0            0       NaN        NaN
# 56                  0                   0            0       NaN        NaN
# 57                  0                   0            0       NaN        NaN
#
#     global  important_slot  Parking Lot  Driveway  Highway  Roadway  \
# 0      NaN             NaN          NaN       NaN      NaN      NaN
# 1      NaN             NaN          NaN       NaN      NaN      NaN
# 2      NaN             NaN          NaN       NaN      NaN      NaN
# 3      NaN             NaN          NaN       NaN      NaN      NaN
# 4      NaN             1.0          NaN       NaN      NaN      NaN
# 5      NaN             1.0          NaN       NaN      NaN      NaN
# 6      NaN             NaN          NaN       NaN      NaN      NaN
# 7      NaN             NaN          NaN       NaN      NaN      NaN
# 8      NaN             NaN          NaN       NaN      NaN      NaN
# 9      NaN             NaN          NaN       NaN      NaN      NaN
# 10     NaN             NaN          NaN       NaN      NaN      NaN
# 11     NaN             1.0          NaN       NaN      NaN      NaN
# 12     NaN             NaN          NaN       NaN      NaN      NaN
# 13     NaN             NaN          NaN       NaN      NaN      NaN
# 14     NaN             NaN          NaN       NaN      NaN      NaN
# 15     NaN             NaN          NaN       NaN      NaN      NaN
# 16     NaN             NaN          NaN       NaN      NaN      NaN
# 17     NaN             NaN          NaN       NaN      NaN      NaN
# 18     NaN             1.0          NaN       NaN      NaN      NaN
# 19     NaN             NaN          NaN       NaN      NaN      NaN
# 20     NaN             NaN          NaN       NaN      NaN      NaN
# 21     NaN             NaN          NaN       NaN      NaN      NaN
# 22     NaN             NaN          NaN       NaN      NaN      NaN
# 23     1.0             NaN          NaN       NaN      NaN      NaN
# 24     NaN             NaN          NaN       1.0      NaN      NaN
# 25     NaN             NaN          NaN       NaN      NaN      NaN
# 26     NaN             NaN          NaN       NaN      NaN      NaN
# 27     NaN             NaN          NaN       NaN      NaN      NaN
# 28     NaN             1.0          NaN       NaN      NaN      NaN
# 29     1.0             1.0          NaN       NaN      NaN      NaN
# 30     NaN             NaN          NaN       NaN      NaN      NaN
# 31     NaN             NaN          NaN       NaN      NaN      NaN
# 32     NaN             NaN          NaN       NaN      NaN      NaN
# 33     NaN             NaN          NaN       NaN      NaN      NaN
# 34     NaN             NaN          NaN       NaN      NaN      NaN
# 35     NaN             NaN          NaN       NaN      NaN      NaN
# 36     1.0             NaN          NaN       NaN      1.0      NaN
# 37     1.0             NaN          NaN       NaN      NaN      NaN
# 38     1.0             NaN          NaN       NaN      NaN      NaN
# 39     NaN             NaN          NaN       NaN      NaN      NaN
# 40     NaN             NaN          NaN       NaN      NaN      NaN
# 41     NaN             NaN          NaN       NaN      NaN      NaN
# 42     NaN             NaN          NaN       NaN      NaN      NaN
# 43     NaN             NaN          NaN       NaN      NaN      NaN
# 44     NaN             NaN          NaN       NaN      NaN      NaN
# 45     NaN             NaN          NaN       NaN      NaN      NaN
# 46     NaN             NaN          NaN       NaN      NaN      NaN
# 47     NaN             NaN          NaN       NaN      NaN      NaN
# 48     1.0             NaN          NaN       NaN      NaN      NaN
# 49     NaN             NaN          NaN       NaN      NaN      NaN
# 50     NaN             NaN          1.0       1.0      NaN      NaN
# 51     NaN             1.0          1.0       1.0      NaN      NaN
# 52     NaN             NaN          1.0       1.0      NaN      NaN
# 53     1.0             1.0          1.0       1.0      NaN      NaN
# 54     NaN             NaN          1.0       1.0      NaN      NaN
# 55     NaN             NaN          1.0       1.0      NaN      NaN
# 56     1.0             NaN          1.0       1.0      NaN      NaN
# 57     1.0             NaN          NaN       NaN      1.0      1.0
#
#     Intersection
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# 51           NaN
# 52           NaN
# 53           NaN
# 54           NaN
# 55           NaN
# 56           NaN
# 57           1.0

# %%
schema = []
for domain_idx, (domain, g) in enumerate(df.groupby("domain")):
    slots = []
    for slot_idx, (_, row) in enumerate(g.iterrows()):
        slot = row["slot"]
        values = []
        for value_idx, value in enumerate(row["value"]):
            values.append({
                "id": f"{domain_idx}-{slot_idx}-{value_idx}",
                "val": value,
            })
        slots.append({
            "id": f"{domain_idx}-{slot_idx}",
            "val": slot,
            "categorical_value": bool(row["categorical_values"]),
            "abstractive_value": bool(row["abstractive_values"]),
            "extractive_value": bool(row["extractive_values"]),
            "time_value": bool(row["time_values"]),
            "values": values,
        })
    schema.append({
        "id": f"{domain_idx}",
        "val": domain,
        "color": colors[domain_idx],
        "slots": slots,
    })

# %%
referents = [
    "Global",
    "Caller",
    "Other Driver",
    "Caller's Passenger",
    "Other Driver's Passenger",
    "Witness",
]

referent_schema = []
for ref_id, ref in enumerate(referents):
    referent_schema.append(
        {
            "id": ref_id,
            "val": ref,
            "color": "#f9800",
        }
    )

schema = {
    "schema": schema,
    "referent_schema": referent_schema,
}

with open(output_path, "w") as f:
    json.dump(schema, f, indent=4)
